# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/facebook_combined.txt', sep=' ', names=['first_node', 'last_node'])
df = df.head(2000)

# %%
df.shape
# Out:
# (2000, 2)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (2000, 2)

# %%
data = {
  "first_node": [420, 380, 390],
  "last_node": [420, 40, 45]
}

df2 = pd.DataFrame(data)
df2.head()
# Out:
#    first_node  last_node
# 0         420        420
# 1         380         40
# 2         390         45

# %%
df3 = df2.apply(lambda x: df.drop(x) if x['first_node'] == x['last_node'] else x, axis=1)
df3.head()
# Out:
# 0          first_node  last_node
# 0              0  ...
# 1    first_node    380
# last_node      40
# Name: 1, d...
# 2    first_node    390
# last_node      45
# Name: 2, d...
# dtype: object

# %%
df4 = df[df['first_node'] != df['last_node']]
df4.shape
# Out:
# (2000, 2)

# %%
df5 = df[df['first_node'] != df['last_node']]
df5
# Out:
#        first_node  last_node
# 0               0          1
# 1               0          2
# 2               0          3
# 3               0          4
# 4               0          5
# ...           ...        ...
# 88229        4026       4030
# 88230        4027       4031
# 88231        4027       4032
# 88232        4027       4038
# 88233        4031       4038
#
# [88234 rows x 2 columns]
